# %% [markdown]
# # Cross-Entropy Method
#
# ---
#
# In this notebook, we will train the Cross-Entropy Method with OpenAI Gym's MountainCarContinuous environment.

# %% [markdown]
# ### 1. Import the Necessary Packages

# %%
import gym
import math
import numpy as np
from collections import deque
import matplotlib.pyplot as plt
# %matplotlib inline

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable

# %% [markdown]
# ### 2. Instantiate the Environment and Agent

# %%
# ref:
# https://www.cnblogs.com/nickchen121/p/15625463.html
# https://github.com/openai/gym/blob/master/gym/envs/classic_control/continuous_mountain_car.py

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

env = gym.make('MountainCarContinuous-v0')
env.seed(101)
np.random.seed(101)

print('observation space:', env.observation_space)
print('action space:', env.action_space)
print('  - low:', env.action_space.low)
print('  - high:', env.action_space.high)

class Agent(nn.Module):
    def __init__(self, env, h_size=16):
        super(Agent, self).__init__()
        self.env = env
        # state, hidden layer, action sizes
        self.s_size = env.observation_space.shape[0]
        self.h_size = h_size
        self.a_size = env.action_space.shape[0]
        # define layers
        self.fc1 = nn.Linear(self.s_size, self.h_size)
        self.fc2 = nn.Linear(self.h_size, self.a_size)
        
    def set_weights(self, weights):
        s_size = self.s_size
        h_size = self.h_size
        a_size = self.a_size
        # separate the weights for each layer
        fc1_end = (s_size*h_size)+h_size
        fc1_W = torch.from_numpy(weights[:s_size*h_size].reshape(s_size, h_size))
        fc1_b = torch.from_numpy(weights[s_size*h_size:fc1_end])
        fc2_W = torch.from_numpy(weights[fc1_end:fc1_end+(h_size*a_size)].reshape(h_size, a_size))
        fc2_b = torch.from_numpy(weights[fc1_end+(h_size*a_size):])
        # set the weights for each layer
        self.fc1.weight.data.copy_(fc1_W.view_as(self.fc1.weight.data))
        self.fc1.bias.data.copy_(fc1_b.view_as(self.fc1.bias.data))
        self.fc2.weight.data.copy_(fc2_W.view_as(self.fc2.weight.data))
        self.fc2.bias.data.copy_(fc2_b.view_as(self.fc2.bias.data))
    
    def get_weights_dim(self):
        return (self.s_size+1)*self.h_size + (self.h_size+1)*self.a_size
        
    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.tanh(self.fc2(x))
        return x.cpu().data
        
    def evaluate(self, weights, gamma=1.0, max_t=5000):
        self.set_weights(weights)
        episode_return = 0.0
        state = self.env.reset()
        for t in range(max_t):
            state = torch.from_numpy(state).float().to(device)
            action = self.forward(state)
            state, reward, done, _ = self.env.step(action)
            # award pos > mid point(-0.5)
            # pos, vel = state
            # reward = abs(pos - (-0.5)) * 0.5
            episode_return += reward * math.pow(gamma, t)
            if done:
                break
        return episode_return
    
agent = Agent(env).to(device)
# Out:
# observation space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
# action space: Box([-1.], [1.], (1,), float32)
#   - low: [-1.]
#   - high: [1.]

# %% [markdown]
# ### 3. Train the Agent with the Cross-Entropy Method
#
# Run the code cell below to train the agent from scratch.  Alternatively, you can skip to the next code cell to load the pre-trained weights from file.

# %%
def cem(n_iterations=500, max_t=1000, gamma=1.0, print_every=10, pop_size=50, elite_frac=0.2, sigma=0.5, best_score=90.0):
    """PyTorch implementation of the cross-entropy method.
        
    Params
    ======
        n_iterations (int): maximum number of training iterations
        max_t (int): maximum number of timesteps per episode
        gamma (float): discount rate
        print_every (int): how often to print average score (over last 100 episodes)
        pop_size (int): size of population at each iteration
        elite_frac (float): percentage of top performers to use in update
        sigma (float): standard deviation of additive noise
    """
    n_elite=int(pop_size*elite_frac)

    scores_deque = deque(maxlen=100)
    scores = []
    best_weight = sigma*np.random.randn(agent.get_weights_dim())
    # best_weight = sigma*np.ones(agent.get_weights_dim())

    for i_iteration in range(1, n_iterations+1):
        weights_pop = [best_weight + (sigma*np.random.randn(agent.get_weights_dim())) for i in range(pop_size)]
        rewards = np.array([agent.evaluate(weights, gamma, max_t) for weights in weights_pop])

        # argsort() return indices for array values from small to big
        elite_idxs = rewards.argsort()[-n_elite:]
        elite_weights = [weights_pop[i] for i in elite_idxs]
        best_weight = np.array(elite_weights).mean(axis=0)

        reward = agent.evaluate(best_weight, gamma=1.0)
        scores_deque.append(reward)
        scores.append(reward)
        
        if i_iteration % print_every == 0:
            print('Episode {}\tAverage Score: {:.2f}'.format(i_iteration, np.mean(scores_deque)))

        if np.mean(scores_deque)>=best_score:
            best_score = np.mean(scores_deque)
            torch.save(agent.state_dict(), 'checkpoint.pth')
            print('\nEnvironment solved in {:d} iterations!\tAverage Score: {:.2f}'.format(i_iteration, np.mean(scores_deque)))
            # break
    return scores

scores = cem()

# plot the scores
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(1, len(scores)+1), scores)
plt.ylabel('Score')
plt.xlabel('Episode #')
plt.show()
# Out:
# Episode 10	Average Score: -8.32
# Episode 20	Average Score: -5.44
# Episode 30	Average Score: -4.32
# Episode 40	Average Score: -3.78
# Episode 50	Average Score: -3.15
# Episode 60	Average Score: -2.82
# Episode 70	Average Score: -2.55
# Episode 80	Average Score: -2.27
# Episode 90	Average Score: -2.08
# Episode 100	Average Score: -1.93
# Episode 110	Average Score: -1.14
# Episode 120	Average Score: -0.92
# Episode 130	Average Score: -0.72
# Episode 140	Average Score: -0.52
# Episode 150	Average Score: -0.47
# Episode 160	Average Score: -0.35
# Episode 170	Average Score: -0.32
# Episode 180	Average Score: -0.30
# Episode 190	Average Score: -0.25
# Episode 200	Average Score: -0.19
# Episode 210	Average Score: 2.19
# Episode 220	Average Score: 10.31
# Episode 230	Average Score: 19.73
# Episode 240	Average Score: 29.32
# Episode 250	Average Score: 38.91
# Episode 260	Average Score: 48.39
# Episode 270	Average Score: 58.01
# Episode 280	Average Score: 67.54
# Episode 290	Average Score: 77.01
# Episode 300	Average Score: 86.51
#
# Environment solved in 304 iterations!	Average Score: 90.49
#
# Environment solved in 305 iterations!	Average Score: 90.57
#
# Environment solved in 306 iterations!	Average Score: 91.56
#
# Environment solved in 307 iterations!	Average Score: 92.55
#
# Environment solved in 308 iterations!	Average Score: 93.65
#
# Environment solved in 309 iterations!	Average Score: 93.76
# Episode 310	Average Score: 93.81
#
# Environment solved in 310 iterations!	Average Score: 93.81
#
# Environment solved in 311 iterations!	Average Score: 93.93
#
# Environment solved in 312 iterations!	Average Score: 93.97
#
# Environment solved in 313 iterations!	Average Score: 95.02
#
# Environment solved in 314 iterations!	Average Score: 95.09
#
# Environment solved in 315 iterations!	Average Score: 95.13
#
# Environment solved in 316 iterations!	Average Score: 95.19
#
# Environment solved in 317 iterations!	Average Score: 95.23
#
# Environment solved in 318 iterations!	Average Score: 95.26
#
# Environment solved in 319 iterations!	Average Score: 95.28
# Episode 320	Average Score: 95.34
#
# Environment solved in 320 iterations!	Average Score: 95.34
#
# Environment solved in 321 iterations!	Average Score: 95.39
#
# Environment solved in 322 iterations!	Average Score: 95.46
#
# Environment solved in 323 iterations!	Average Score: 95.49
#
# Environment solved in 327 iterations!	Average Score: 95.50
#
# Environment solved in 329 iterations!	Average Score: 95.57
# Episode 330	Average Score: 95.59
#
# Environment solved in 330 iterations!	Average Score: 95.59
#
# Environment solved in 331 iterations!	Average Score: 95.60
#
# Environment solved in 332 iterations!	Average Score: 95.60
# Episode 340	Average Score: 95.56
#
# Environment solved in 348 iterations!	Average Score: 95.60
#
# Environment solved in 349 iterations!	Average Score: 95.64
# Episode 350	Average Score: 95.65
#
# Environment solved in 350 iterations!	Average Score: 95.65
#
# Environment solved in 351 iterations!	Average Score: 95.66
#
# Environment solved in 352 iterations!	Average Score: 95.66
#
# Environment solved in 353 iterations!	Average Score: 95.67
#
# Environment solved in 354 iterations!	Average Score: 95.69
#
# Environment solved in 356 iterations!	Average Score: 95.73
#
# Environment solved in 357 iterations!	Average Score: 95.76
#
# Environment solved in 358 iterations!	Average Score: 95.78
#
# Environment solved in 359 iterations!	Average Score: 95.80
# Episode 360	Average Score: 95.82
#
# Environment solved in 360 iterations!	Average Score: 95.82
#
# Environment solved in 361 iterations!	Average Score: 95.82
#
# Environment solved in 366 iterations!	Average Score: 95.82
#
# Environment solved in 367 iterations!	Average Score: 95.84
#
# Environment solved in 368 iterations!	Average Score: 95.87
#
# Environment solved in 369 iterations!	Average Score: 95.89
# Episode 370	Average Score: 95.90
#
# Environment solved in 370 iterations!	Average Score: 95.90
#
# Environment solved in 372 iterations!	Average Score: 95.90
#
# Environment solved in 373 iterations!	Average Score: 95.95
#
# Environment solved in 374 iterations!	Average Score: 95.96
#
# Environment solved in 375 iterations!	Average Score: 95.98
#
# Environment solved in 376 iterations!	Average Score: 95.99
#
# Environment solved in 377 iterations!	Average Score: 96.01
#
# Environment solved in 378 iterations!	Average Score: 96.02
#
# Environment solved in 379 iterations!	Average Score: 96.03
# Episode 380	Average Score: 96.05
#
# Environment solved in 380 iterations!	Average Score: 96.05
#
# Environment solved in 381 iterations!	Average Score: 96.06
#
# Environment solved in 382 iterations!	Average Score: 96.06
#
# Environment solved in 383 iterations!	Average Score: 96.08
#
# Environment solved in 384 iterations!	Average Score: 96.09
#
# Environment solved in 385 iterations!	Average Score: 96.11
#
# Environment solved in 386 iterations!	Average Score: 96.14
#
# Environment solved in 387 iterations!	Average Score: 96.16
#
# Environment solved in 388 iterations!	Average Score: 96.19
#
# Environment solved in 389 iterations!	Average Score: 96.22
# Episode 390	Average Score: 96.24
#
# Environment solved in 390 iterations!	Average Score: 96.24
#
# Environment solved in 391 iterations!	Average Score: 96.26
#
# Environment solved in 392 iterations!	Average Score: 96.27
#
# Environment solved in 398 iterations!	Average Score: 96.29
#
# Environment solved in 399 iterations!	Average Score: 96.31
# Episode 400	Average Score: 96.25
# Episode 410	Average Score: 96.24
#
# Environment solved in 415 iterations!	Average Score: 96.34
#
# Environment solved in 416 iterations!	Average Score: 96.34
#
# Environment solved in 417 iterations!	Average Score: 96.36
#
# Environment solved in 418 iterations!	Average Score: 96.36
# Episode 420	Average Score: 96.35
#
# Environment solved in 423 iterations!	Average Score: 96.37
#
# Environment solved in 424 iterations!	Average Score: 96.37
# Episode 430	Average Score: 96.35
#
# Environment solved in 433 iterations!	Average Score: 96.42
#
# Environment solved in 434 iterations!	Average Score: 96.43
#
# Environment solved in 435 iterations!	Average Score: 96.47
#
# Environment solved in 436 iterations!	Average Score: 96.49
# Episode 440	Average Score: 96.46
# Episode 450	Average Score: 96.44
# Episode 460	Average Score: 96.47
#
# Environment solved in 462 iterations!	Average Score: 96.49
#
# Environment solved in 463 iterations!	Average Score: 96.50
#
# Environment solved in 466 iterations!	Average Score: 96.53
#
# Environment solved in 467 iterations!	Average Score: 96.53
# Episode 470	Average Score: 96.49
# Episode 480	Average Score: 96.50
#
# Environment solved in 488 iterations!	Average Score: 96.54
# Episode 490	Average Score: 96.53
#
# Environment solved in 493 iterations!	Average Score: 96.56
#
# Environment solved in 494 iterations!	Average Score: 96.57
#
# Environment solved in 495 iterations!	Average Score: 96.58
#
# Environment solved in 496 iterations!	Average Score: 96.58
# Episode 500	Average Score: 96.63
#
# Environment solved in 500 iterations!	Average Score: 96.63

# %% [markdown]
# ### 4. Watch a Smart Agent!
#
# In the next code cell, you will load the trained weights from file to watch a smart agent!

# %%
# load the weights from file
agent.load_state_dict(torch.load('checkpoint.pth'))

state = env.reset()
while True:
    state = torch.from_numpy(state).float().to(device)
    with torch.no_grad():
        action = agent(state)
    env.render()
    next_state, reward, done, _ = env.step(action)
    state = next_state
    if done:
        break

env.close()
